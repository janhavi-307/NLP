# %% [markdown]
# # Assignment 7 - Develop a text preprocessing and analysis application using NLTK for tokenization, POS tagging, and basic NLP tasks.

# %%
# !pip install nltk streamlit matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (3.9.1)
# Requirement already satisfied: streamlit in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (1.37.1)
# Requirement already satisfied: matplotlib in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (3.9.0)
# Requirement already satisfied: click in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from nltk) (4.67.0)
# Requirement already satisfied: altair<6,>=4.0 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from streamlit) (5.4.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from streamlit) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: numpy<3,>=1.20 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from streamlit) (2.1.4)
# Requirement already satisfied: pillow<11,>=7.1.0 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from streamlit) (17.0.0)
# Requirement already satisfied: requests<3,>=2.27 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: rich<14,>=10.14.0 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from streamlit) (4.0.2)
# Requirement already satisfied: jinja2 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from altair<6,>=4.0->streamlit) (4.22.0)
# Requirement already satisfied: narwhals>=1.1.0 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from altair<6,>=4.0->streamlit) (2.4.0)
# Requirement already satisfied: colorama in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: smmap<6,>=3.0.1 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from requests<3,>=2.27->streamlit) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from requests<3,>=2.27->streamlit) (2024.6.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.1)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in C:\Users\SRINIDHI\AppData\Roaming\Python\Python312\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)

# %%
import nltk

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\SRINIDHI\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\SRINIDHI\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\SRINIDHI\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\SRINIDHI\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\SRINIDHI\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\SRINIDHI\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\SRINIDHI\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\SRINIDHI\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
import string
import matplotlib.pyplot as plt
from collections import Counter

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk import pos_tag, ne_chunk
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
text = """
India is rapidly growing in the field of Artificial Intelligence.
Many companies like Google and Microsoft are investing heavily in AI research.
"""

# %%
sentences = sent_tokenize(text)
words = word_tokenize(text.lower())

words = [w for w in words if w not in string.punctuation]

print("Sentences:\n", sentences)
print("\nWords:\n", words)
# Out:
# Sentences:
#  ['\nIndia is rapidly growing in the field of Artificial Intelligence.', 'Many companies like Google and Microsoft are investing heavily in AI research.']
#
# Words:
#  ['india', 'is', 'rapidly', 'growing', 'in', 'the', 'field', 'of', 'artificial', 'intelligence', 'many', 'companies', 'like', 'google', 'and', 'microsoft', 'are', 'investing', 'heavily', 'in', 'ai', 'research']

# %%
stop_words = set(stopwords.words('english'))
filtered_words = [w for w in words if w not in stop_words]

print("Filtered Words:\n", filtered_words)
# Out:
# Filtered Words:
#  ['india', 'rapidly', 'growing', 'field', 'artificial', 'intelligence', 'many', 'companies', 'like', 'google', 'microsoft', 'investing', 'heavily', 'ai', 'research']

# %%
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

stems = [stemmer.stem(w) for w in filtered_words]
lemmas = [lemmatizer.lemmatize(w) for w in filtered_words]

print("Stems:\n", stems)
print("\nLemmas:\n", lemmas)
# Out:
# Stems:
#  ['india', 'rapidli', 'grow', 'field', 'artifici', 'intellig', 'mani', 'compani', 'like', 'googl', 'microsoft', 'invest', 'heavili', 'ai', 'research']
#
# Lemmas:
#  ['india', 'rapidly', 'growing', 'field', 'artificial', 'intelligence', 'many', 'company', 'like', 'google', 'microsoft', 'investing', 'heavily', 'ai', 'research']

# %%
pos_tags = pos_tag(filtered_words)
print("POS Tags:\n", pos_tags)
# Out:
# POS Tags:
#  [('india', 'RB'), ('rapidly', 'RB'), ('growing', 'VBG'), ('field', 'NN'), ('artificial', 'JJ'), ('intelligence', 'NN'), ('many', 'JJ'), ('companies', 'NNS'), ('like', 'IN'), ('google', 'NN'), ('microsoft', 'NN'), ('investing', 'VBG'), ('heavily', 'RB'), ('ai', 'VBP'), ('research', 'NN')]

# %%
nltk.download('maxent_ne_chunker')
nltk.download('maxent_ne_chunker_tab')   # VERY IMPORTANT
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\SRINIDHI\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\SRINIDHI\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\SRINIDHI\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
ner_tree = ne_chunk(pos_tags)
print("Named Entities:\n")
print(ner_tree)
# Out:
# Named Entities:
#
# (S
#   india/RB
#   rapidly/RB
#   growing/VBG
#   field/NN
#   artificial/JJ
#   intelligence/NN
#   many/JJ
#   companies/NNS
#   like/IN
#   google/NN
#   microsoft/NN
#   investing/VBG
#   heavily/RB
#   ai/VBP
#   research/NN)

# %%
sia = SentimentIntensityAnalyzer()
sentiment = sia.polarity_scores(text)

print("Sentiment Scores:\n", sentiment)
# Out:
# Sentiment Scores:
#  {'neg': 0.0, 'neu': 0.722, 'pos': 0.278, 'compound': 0.743}

# %%
freq = Counter(filtered_words)

common_words = freq.most_common(10)

words_plot = [x[0] for x in common_words]
counts_plot = [x[1] for x in common_words]

plt.figure()
plt.bar(words_plot, counts_plot)
plt.xticks(rotation=45)
plt.title("Top 10 Frequent Words")
plt.show()
